# %%
# IMPORTANT! RUN THIS CELL BEFORE ANYTHING ELSE!
from typing import Callable, cast
from sklearn.exceptions import NotFittedError
from sklearn.utils.validation import check_is_fitted
from IPython.display import display
from pathlib import Path
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from ydata_profiling import ProfileReport
import pandas as pd
import pandas._typing
import numpy as np

class StopExecution(Exception):
    def _render_traceback_(self):
        return []


def compare_metrics(
    metrics_1: dict[str, float],
    metrics_2: dict[str, float],
    name_1: str,
    name_2: str,
) -> pd.DataFrame:
    """
    Return a DataFrame comparing the metrics of two experiments.
    """
    return pd.DataFrame(
        [metrics_1, metrics_2],
        index=cast(pandas._typing.Axes, [name_1, name_2]),
    ).T.assign(Delta=lambda df: df[name_1] - df[name_2])

# %%
data_raw = pd.read_csv("data/Bacteria_dataset_Multiresictance.csv")
data_raw.head()
# Out:
#      ID                Name                           Email  \
# 0  S290  Elizabeth Lawrence  elizabeth.lawrence@example.com
# 1  S291        Tina Sanders        tina.sanders@example.com
# 2  S292          Erin Cooke          erin.cooke@example.com
# 3  S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com
# 4  S294       Erika Stewart       erika.stewart@example.com
#
#                                              Address age/gender  \
# 0    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252       37/F
# 1  78594 Galloway Port Suite 762, South Tanyatown...       29/F
# 2      76661 Isaiah Manors, North Benjamin, HI 85195       77/F
# 3   1670 Thompson Way Apt. 520, Andrewbury, IL 11534        NaN
# 4  76838 Patrick Green Suite 538, Torresmouth, ME...       13/F
#
#                     Souches Diabetes Hypertension Hospital_before  \
# 0     S290 Escherichia coli       No           No              No
# 1  S291 Morganella morganii     True           No              No
# 2    S292 Proteus mirabilis     True           No              No
# 3                       NaN      NaN          NaN             NaN
# 4     S294 Escherichia coli       No          Yes              No
#
#   Infection_Freq  ...   AN Acide nalidixique  ofx  CIP    C Co-trimoxazole  \
# 0            0.0  ...    S                 S    S    S    R              S
# 1            3.0  ...    S                 S    S    S    S              S
# 2            3.0  ...    S                 S    S    R    R              S
# 3            NaN  ...  NaN               NaN  NaN  NaN  NaN            NaN
# 4            1.0  ...    R                 S    S    S    S              S
#
#   Furanes colistine Collection_Date                Notes
# 0       S         S      5 Fev 2025  Patient had fever??
# 1       S         S      08/05/2021            تم العلاج
# 2       S         S      01/05/2022                 NADA
# 3     NaN       NaN      2020-01-05     PACIENTO ENFERMO
# 4       S         S           error                 NADA
#
# [5 rows x 27 columns]

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 10710 non-null  object
#  1   Name               10710 non-null  object
#  2   Email              10710 non-null  object
#  3   Address            10710 non-null  object
#  4   age/gender         10089 non-null  object
#  5   Souches            10070 non-null  object
#  6   Diabetes           10075 non-null  object
#  7   Hypertension       10080 non-null  object
#  8   Hospital_before    10073 non-null  object
#  9   Infection_Freq     10071 non-null  object
#  10  AMX/AMP            10052 non-null  object
#  11  AMC                10078 non-null  object
#  12  CZ                 10082 non-null  object
#  13  FOX                10085 non-null  object
#  14  CTX/CRO            10086 non-null  object
#  15  IPM                10077 non-null  object
#  16  GEN                10067 non-null  object
#  17  AN                 10082 non-null  object
#  18  Acide nalidixique  10088 non-null  object
#  19  ofx                10092 non-null  object
#  20  CIP                10077 non-null  object
#  21  C                  10081 non-null  object
#  22  Co-trimoxazole     10070 non-null  object
#  23  Furanes            10073 non-null  object
#  24  colistine          10074 non-null  object
#  25  Collection_Date    10041 non-null  object
#  26  Notes              10598 non-null  object
# dtypes: object(27)
# memory usage: 2.2+ MB

# %%
# Normalizing data for Nan values

missing_tokens = ['?', 'missing', 'Missing', 'None', 'none', '', 'NaN', 'nan']
data_raw.replace(to_replace=missing_tokens, value=np.nan, inplace=True)

# %%
data_raw.isna().sum()
# Out:
# ID                      0
# Name                    0
# Email                   0
# Address                 0
# age/gender            763
# Souches               763
# Diabetes              763
# Hypertension          763
# Hospital_before       763
# Infection_Freq        834
# AMX/AMP               753
# AMC                   753
# CZ                    753
# FOX                   753
# CTX/CRO               753
# IPM                   753
# GEN                   753
# AN                    753
# Acide nalidixique     753
# ofx                   753
# CIP                   753
# C                     753
# Co-trimoxazole        753
# Furanes               753
# colistine             753
# Collection_Date      1807
# Notes                 244
# dtype: int64

# %%
data_raw.columns = (
    data_raw.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
)

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10710 non-null  object
#  1   name               10710 non-null  object
#  2   email              10710 non-null  object
#  3   address            10710 non-null  object
#  4   age/gender         9947 non-null   object
#  5   souches            9947 non-null   object
#  6   diabetes           9947 non-null   object
#  7   hypertension       9947 non-null   object
#  8   hospital_before    9947 non-null   object
#  9   infection_freq     9876 non-null   object
#  10  amx/amp            9957 non-null   object
#  11  amc                9957 non-null   object
#  12  cz                 9957 non-null   object
#  13  fox                9957 non-null   object
#  14  ctx/cro            9957 non-null   object
#  15  ipm                9957 non-null   object
#  16  gen                9957 non-null   object
#  17  an                 9957 non-null   object
#  18  acide_nalidixique  9957 non-null   object
#  19  ofx                9957 non-null   object
#  20  cip                9957 non-null   object
#  21  c                  9957 non-null   object
#  22  co-trimoxazole     9957 non-null   object
#  23  furanes            9957 non-null   object
#  24  colistine          9957 non-null   object
#  25  collection_date    8903 non-null   object
#  26  notes              10466 non-null  object
# dtypes: object(27)
# memory usage: 2.2+ MB

# %%
data = data_raw.drop(columns=["notes"])
PROFILE_REPORT_PATH = Path("profile.html")
if PROFILE_REPORT_PATH.exists():
    PROFILE_REPORT_PATH.unlink(missing_ok=True)
    print("Existing profile report removed")
ProfileReport(data, title="Profiling Report on Bacteria Dataset").to_file(PROFILE_REPORT_PATH)
if not PROFILE_REPORT_PATH.exists():
    raise StopExecution(
        f"The profile report was not generated at {PROFILE_REPORT_PATH}"
    )
# Out:
# Existing profile report removed
# 100%|██████████| 25/25 [00:00<00:00, 129.47it/s]<00:00, 31.03it/s, Describe variable: colistine_norm]
# Summarize dataset: 100%|██████████| 36/36 [00:02<00:00, 13.09it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 159.15it/s]

# %%
# Split age/gender column into two separate columns
def split_age_gender(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df[["age", "gender"]] = df["age/gender"].str.split("/", expand=True)
    df.drop(columns=["age/gender"], inplace=True)
    return df
data_raw = split_age_gender(data_raw)

# %%
data_raw.head()
# Out:
#      id                name                           email  \
# 0  S290  Elizabeth Lawrence  elizabeth.lawrence@example.com
# 1  S291        Tina Sanders        tina.sanders@example.com
# 2  S292          Erin Cooke          erin.cooke@example.com
# 3  S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com
# 4  S294       Erika Stewart       erika.stewart@example.com
#
#                                              address  \
# 0    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252
# 1  78594 Galloway Port Suite 762, South Tanyatown...
# 2      76661 Isaiah Manors, North Benjamin, HI 85195
# 3   1670 Thompson Way Apt. 520, Andrewbury, IL 11534
# 4  76838 Patrick Green Suite 538, Torresmouth, ME...
#
#                     souches diabetes hypertension hospital_before  \
# 0     S290 Escherichia coli       No           No              No
# 1  S291 Morganella morganii     True           No              No
# 2    S292 Proteus mirabilis     True           No              No
# 3                       NaN      NaN          NaN             NaN
# 4     S294 Escherichia coli       No          Yes              No
#
#   infection_freq amx/amp  ...  ofx  cip    c co-trimoxazole furanes colistine  \
# 0            0.0       R  ...    S    S    R              S       S         S
# 1            3.0       S  ...    S    S    S              S       S         S
# 2            3.0       S  ...    S    R    R              S       S         S
# 3            NaN     NaN  ...  NaN  NaN  NaN            NaN     NaN       NaN
# 4            1.0       S  ...    S    S    S              S       S         S
#
#   collection_date                notes  age gender
# 0      5 Fev 2025  Patient had fever??   37      F
# 1      08/05/2021            تم العلاج   29      F
# 2      01/05/2022                 NADA   77      F
# 3      2020-01-05     PACIENTO ENFERMO  NaN    NaN
# 4           error                 NADA   13      F
#
# [5 rows x 28 columns]

# %%
# Splitting Souches column
def split_id_strain(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df[['strain_code', 'strain']] = df['souches'].str.split(' ', n=1, expand=True) 
    df.drop(columns=["strain_code","souches"], inplace=True)
    return df 
data_raw = split_id_strain(data_raw)

# %%
data_raw.head()
# Out:
#      id                name                           email  \
# 0  S290  Elizabeth Lawrence  elizabeth.lawrence@example.com
# 1  S291        Tina Sanders        tina.sanders@example.com
# 2  S292          Erin Cooke          erin.cooke@example.com
# 3  S293  Mrs. Sharon Watson  mrs..sharon.watson@example.com
# 4  S294       Erika Stewart       erika.stewart@example.com
#
#                                              address diabetes hypertension  \
# 0    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252       No           No
# 1  78594 Galloway Port Suite 762, South Tanyatown...     True           No
# 2      76661 Isaiah Manors, North Benjamin, HI 85195     True           No
# 3   1670 Thompson Way Apt. 520, Andrewbury, IL 11534      NaN          NaN
# 4  76838 Patrick Green Suite 538, Torresmouth, ME...       No          Yes
#
#   hospital_before infection_freq amx/amp  amc  ...  cip    c co-trimoxazole  \
# 0              No            0.0       R    R  ...    S    R              S
# 1              No            3.0       S    R  ...    S    S              S
# 2              No            3.0       S    R  ...    R    R              S
# 3             NaN            NaN     NaN  NaN  ...  NaN  NaN            NaN
# 4              No            1.0       S    S  ...    S    S              S
#
#   furanes colistine collection_date                notes  age gender  \
# 0       S         S      5 Fev 2025  Patient had fever??   37      F
# 1       S         S      08/05/2021            تم العلاج   29      F
# 2       S         S      01/05/2022                 NADA   77      F
# 3     NaN       NaN      2020-01-05     PACIENTO ENFERMO  NaN    NaN
# 4       S         S           error                 NADA   13      F
#
#                 strain
# 0     Escherichia coli
# 1  Morganella morganii
# 2    Proteus mirabilis
# 3                  NaN
# 4     Escherichia coli
#
# [5 rows x 28 columns]

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10710 non-null  object
#  1   name               10710 non-null  object
#  2   email              10710 non-null  object
#  3   address            10710 non-null  object
#  4   diabetes           9947 non-null   object
#  5   hypertension       9947 non-null   object
#  6   hospital_before    9947 non-null   object
#  7   infection_freq     9876 non-null   object
#  8   amx/amp            9957 non-null   object
#  9   amc                9957 non-null   object
#  10  cz                 9957 non-null   object
#  11  fox                9957 non-null   object
#  12  ctx/cro            9957 non-null   object
#  13  ipm                9957 non-null   object
#  14  gen                9957 non-null   object
#  15  an                 9957 non-null   object
#  16  acide_nalidixique  9957 non-null   object
#  17  ofx                9957 non-null   object
#  18  cip                9957 non-null   object
#  19  c                  9957 non-null   object
#  20  co-trimoxazole     9957 non-null   object
#  21  furanes            9957 non-null   object
#  22  colistine          9957 non-null   object
#  23  collection_date    8903 non-null   object
#  24  notes              10466 non-null  object
#  25  age                9947 non-null   object
#  26  gender             9947 non-null   object
#  27  strain             9947 non-null   object
# dtypes: object(28)
# memory usage: 2.3+ MB

# %%
data_raw["strain"].value_counts()
# Out:
# strain
# Escherichia coli           4864
# Enterobacteria spp.         802
# Proteus mirabilis           598
# Klebsiella pneumoniae       565
# Citrobacter spp.            481
# E.coi                       432
# E.cli                       396
# E. coli                     391
# Morganella morganii         305
# Serratia marcescens         256
# Pseudomonas aeruginosa      200
# Acinetobacter baumannii     181
# Enter.bacteria spp.         100
# Enteobacteria spp.           95
# Klbsiella pneumoniae         74
# Klebsie.lla pneumoniae       63
# Protus mirabilis             51
# Proeus mirabilis             47
# Prot.eus mirabilis           46
# Name: count, dtype: int64

# %%
data_raw["strain_clean"] = (
    data_raw["strain"]
    .str.lower()
    .str.replace(r"[^a-z\s\.]", "", regex=True)  # supprime caractères parasites
    .str.replace(r"\s+", " ", regex=True)        # espaces multiples → un espace
    .str.strip()                                 # supprime espaces en trop
)

# %%
data_raw["strain_clean"].value_counts()
# Out:
# strain_clean
# escherichia coli           4864
# enterobacteria spp.         802
# proteus mirabilis           598
# klebsiella pneumoniae       565
# citrobacter spp.            481
# e.coi                       432
# e.cli                       396
# e. coli                     391
# morganella morganii         305
# serratia marcescens         256
# pseudomonas aeruginosa      200
# acinetobacter baumannii     181
# enter.bacteria spp.         100
# enteobacteria spp.           95
# klbsiella pneumoniae         74
# klebsie.lla pneumoniae       63
# protus mirabilis             51
# proeus mirabilis             47
# prot.eus mirabilis           46
# Name: count, dtype: int64

# %%
def normalize_bacteria(name: str) -> str:

    if pd.isna(name):
        return name

    name = name.lower().strip()

    if "coli" in name or "coi" in name or "cli" in name:
        return "Escherichia coli"
    elif "enterobacter" in name or "ente" in name:
        return "Enterobacteria spp."
    elif "proteus" in name or "protus" in name or "proeus" in name or "prot" in name:
        return "Proteus mirabilis"
    elif "klebsiella" in name or "klbsiella" in name or "klebsie" in name:
        return "Klebsiella pneumoniae"
    elif "citrobacter" in name:
        return "Citrobacter spp."
    elif "morganella" in name:
        return "Morganella morganii"
    elif "serratia" in name:
        return "Serratia marcescens"
    elif "pseudomonas" in name:
        return "Pseudomonas aeruginosa"
    elif "acinetobacter" in name:
        return "Acinetobacter baumannii"
    else:
        return name.capitalize()

# %%
data_raw["strain_norm"] = data_raw["strain_clean"].apply(normalize_bacteria)

# %%
data_raw["strain_norm"].value_counts()
# Out:
# strain_norm
# Escherichia coli           6083
# Enterobacteria spp.         997
# Proteus mirabilis           742
# Klebsiella pneumoniae       702
# Citrobacter spp.            481
# Morganella morganii         305
# Serratia marcescens         256
# Pseudomonas aeruginosa      200
# Acinetobacter baumannii     181
# Name: count, dtype: int64

# %%
data_raw.drop(columns=["strain", "strain_clean"], inplace=True)

# %%
# Remove name, email columns to respect RGPD
data_raw.drop(columns=["name", "email"], inplace=True)

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10710 entries, 0 to 10709
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10710 non-null  object
#  1   address            10710 non-null  object
#  2   diabetes           9947 non-null   object
#  3   hypertension       9947 non-null   object
#  4   hospital_before    9947 non-null   object
#  5   infection_freq     9876 non-null   object
#  6   amx/amp            9957 non-null   object
#  7   amc                9957 non-null   object
#  8   cz                 9957 non-null   object
#  9   fox                9957 non-null   object
#  10  ctx/cro            9957 non-null   object
#  11  ipm                9957 non-null   object
#  12  gen                9957 non-null   object
#  13  an                 9957 non-null   object
#  14  acide_nalidixique  9957 non-null   object
#  15  ofx                9957 non-null   object
#  16  cip                9957 non-null   object
#  17  c                  9957 non-null   object
#  18  co-trimoxazole     9957 non-null   object
#  19  furanes            9957 non-null   object
#  20  colistine          9957 non-null   object
#  21  collection_date    8903 non-null   object
#  22  notes              10466 non-null  object
#  23  age                9947 non-null   object
#  24  gender             9947 non-null   object
#  25  strain_norm        9947 non-null   object
# dtypes: object(26)
# memory usage: 2.1+ MB

# %%
# Pipeline for preprocessing using transformers
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
def norm_ast(v):
    if pd.isna(v): 
        return np.nan
    s = str(v).strip().upper()
    if s=='' or s in {'NA','N/A','?','MISSING'}: 
        return np.nan
    if s.startswith('R'): 
        return 'R'
    if s.startswith('S'): 
        return 'S'
    if s.startswith('I') or 'INTER' in s: 
        return 'I'
    return np.nan

# %%
ab_cols = [
    'amx/amp', 'amc', 'cz', 'fox', 'ctx/cro', 'ipm', 'gen',
    'an', 'acide_nalidixique', 'ofx', 'cip', 'c',
    'co-trimoxazole', 'furanes', 'colistine'
]
print("auto-detected antibiotic cols:", ab_cols)


print("--- Unique Values per Column ---")
print("-" * 35)

# --- 3. Iterate and print unique values ---
for column in ab_cols:
    # Use .unique() to get all unique values, including NaN/None
    unique_values = data_raw[column].unique()
    
    # Print the column name and the resulting unique array
    # .tolist() converts the numpy array (output of .unique()) to a standard Python list for cleaner printing
    print(f"Column: {column}")
    print(f"  Unique Values: {unique_values.tolist()}")
    print("-" * 35)
# Out:
# auto-detected antibiotic cols: ['amx/amp', 'amc', 'cz', 'fox', 'ctx/cro', 'ipm', 'gen', 'an', 'acide_nalidixique', 'ofx', 'cip', 'c', 'co-trimoxazole', 'furanes', 'colistine']
# --- Unique Values per Column ---
# -----------------------------------
# Column: amx/amp
#   Unique Values: ['R', 'S', nan, 's', 'i', 'r', 'Intermediate']
# -----------------------------------
# Column: amc
#   Unique Values: ['R', nan, 'S', 's', 'r', 'Intermediate', 'i']
# -----------------------------------
# Column: cz
#   Unique Values: ['R', 'S', nan, 'r', 'Intermediate', 'i', 's']
# -----------------------------------
# Column: fox
#   Unique Values: ['R', nan, 'S', 's', 'i', 'Intermediate', 'r']
# -----------------------------------
# Column: ctx/cro
#   Unique Values: ['R', 'S', nan, 'r', 'i', 's', 'Intermediate']
# -----------------------------------
# Column: ipm
#   Unique Values: ['R', 'S', nan, 'i', 'Intermediate', 's', 'r']
# -----------------------------------
# Column: gen
#   Unique Values: ['S', nan, 'R', 'i', 's', 'r', 'Intermediate']
# -----------------------------------
# Column: an
#   Unique Values: ['S', nan, 'R', 'i', 's', 'Intermediate', 'r']
# -----------------------------------
# Column: acide_nalidixique
#   Unique Values: ['S', nan, 'R', 'Intermediate', 's', 'r', 'i']
# -----------------------------------
# Column: ofx
#   Unique Values: ['S', nan, 'R', 'r', 'Intermediate', 's', 'i']
# -----------------------------------
# Column: cip
#   Unique Values: ['S', 'R', nan, 's', 'Intermediate', 'i', 'r']
# -----------------------------------
# Column: c
#   Unique Values: ['R', 'S', nan, 'Intermediate', 'i', 'r', 's']
# -----------------------------------
# Column: co-trimoxazole
#   Unique Values: ['S', nan, 'R', 'Intermediate', 's', 'r', 'i']
# -----------------------------------
# Column: furanes
#   Unique Values: ['S', nan, 'R', 'i', 's', 'r', 'Intermediate']
# -----------------------------------
# Column: colistine
#   Unique Values: ['S', nan, 'R', 'r', 'i', 's', 'Intermediate']
# -----------------------------------

# %%
for c in ab_cols:
    data_raw[c+"_norm"] = data_raw[c].apply(norm_ast)
    data_raw.drop(columns=[c], inplace=True)

# %%
data_raw.head()
# Out:
#      id                                            address diabetes  \
# 0  S290    6350 Robinson Loaf Apt. 447, Paulfurt, RI 30252       No
# 1  S291  78594 Galloway Port Suite 762, South Tanyatown...     True
# 2  S292      76661 Isaiah Manors, North Benjamin, HI 85195     True
# 3  S293   1670 Thompson Way Apt. 520, Andrewbury, IL 11534      NaN
# 4  S294  76838 Patrick Green Suite 538, Torresmouth, ME...       No
#
#   hypertension hospital_before infection_freq collection_date  \
# 0           No              No            0.0      5 Fev 2025
# 1           No              No            3.0      08/05/2021
# 2           No              No            3.0      01/05/2022
# 3          NaN             NaN            NaN      2020-01-05
# 4          Yes              No            1.0           error
#
#                  notes  age gender  ... ipm_norm gen_norm an_norm  \
# 0  Patient had fever??   37      F  ...        R        S       S
# 1            تم العلاج   29      F  ...        R        S       S
# 2                 NADA   77      F  ...        S        S       S
# 3     PACIENTO ENFERMO  NaN    NaN  ...      NaN      NaN     NaN
# 4                 NADA   13      F  ...        R        R       R
#
#   acide_nalidixique_norm ofx_norm cip_norm c_norm co-trimoxazole_norm  \
# 0                      S        S        S      R                   S
# 1                      S        S        S      S                   S
# 2                      S        S        R      R                   S
# 3                    NaN      NaN      NaN    NaN                 NaN
# 4                      S        S        S      S                   S
#
#   furanes_norm colistine_norm
# 0            S              S
# 1            S              S
# 2            S              S
# 3          NaN            NaN
# 4            S              S
#
# [5 rows x 26 columns]

# %%
import seaborn as sns

# %%
# Checking for Duplicated values
duplicate_rows = data_raw[data_raw.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [id, address, diabetes, hypertension, hospital_before, infection_freq, collection_date, notes, age, gender, strain_norm, amx/amp_norm, amc_norm, cz_norm, fox_norm, ctx/cro_norm, ipm_norm, gen_norm, an_norm, acide_nalidixique_norm, ofx_norm, cip_norm, c_norm, co-trimoxazole_norm, furanes_norm, colistine_norm]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Unique values 
print(f"unique values of column diabetes : {data_raw['diabetes'].unique()}")
print(f"unique values of column hypertension : {data_raw['hypertension'].unique()}")
print(f"unique values of column hospital_before : {data_raw['hospital_before'].unique()}")
# Out:
# unique values of column diabetes : ['No' 'True' nan]
# unique values of column hypertension : ['No' nan 'Yes']
# unique values of column hospital_before : ['No' nan 'Yes']

# %%
# Normalizing Unique values
bool_map = {'No': False, 'Yes': True, 'True': True}

bool_cols = ['diabetes', 'hypertension', 'hospital_before']

for col in bool_cols:
    data_raw[col] = data_raw[col].map(bool_map).astype('boolean')

# %%
data_raw.isna().sum()
# Out:
# id                           0
# address                      0
# diabetes                   763
# hypertension               763
# hospital_before            763
# infection_freq             834
# collection_date           1807
# notes                      244
# age                        763
# gender                     763
# strain_norm                763
# amx/amp_norm               753
# amc_norm                   753
# cz_norm                    753
# fox_norm                   753
# ctx/cro_norm               753
# ipm_norm                   753
# gen_norm                   753
# an_norm                    753
# acide_nalidixique_norm     753
# ofx_norm                   753
# cip_norm                   753
# c_norm                     753
# co-trimoxazole_norm        753
# furanes_norm               753
# colistine_norm             753
# dtype: int64

# %%
data_raw["collection_date"].value_counts()
# Out:
# collection_date
# 2024-12-31    1461
# 2020-01-05    1337
# 08/05/2021     719
# 5 Fev 2025     712
# 05/01/2025     708
# 05/03/2022     696
# 2023-12-31     693
# 2020-12-31     693
# 01/05/2022     692
# 3 Jan 1019     684
# error          508
# Name: count, dtype: int64

# %%
sns.heatmap(data_raw.isna())
# Out:
# <Axes: >

# %%
# Droping row with all Nan values
# Count rows before dropping
before = len(data_raw)

# Drop rows where all columns EXCEPT ['id', 'address','collection_date','notes'] are NaN
data_raw.dropna(
    axis=0,
    how='all',
    subset=[col for col in data_raw.columns if col not in ['id', "address", "collection_date", "notes"]],
    inplace=True
)

# Reset the index
data_raw.reset_index(drop=True, inplace=True)

# Count rows after dropping and show how many were removed
after = len(data_raw)
print(f"Rows dropped: {before - after}")
# Out:
# Rows dropped: 750

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9960 entries, 0 to 9959
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9960 non-null   object
#  1   address                 9960 non-null   object
#  2   diabetes                9947 non-null   boolean
#  3   hypertension            9947 non-null   boolean
#  4   hospital_before         9947 non-null   boolean
#  5   infection_freq          9876 non-null   object
#  6   collection_date         8474 non-null   object
#  7   notes                   9960 non-null   object
#  8   age                     9947 non-null   object
#  9   gender                  9947 non-null   object
#  10  strain_norm             9947 non-null   object
#  11  amx/amp_norm            9957 non-null   object
#  12  amc_norm                9957 non-null   object
#  13  cz_norm                 9957 non-null   object
#  14  fox_norm                9957 non-null   object
#  15  ctx/cro_norm            9957 non-null   object
#  16  ipm_norm                9957 non-null   object
#  17  gen_norm                9957 non-null   object
#  18  an_norm                 9957 non-null   object
#  19  acide_nalidixique_norm  9957 non-null   object
#  20  ofx_norm                9957 non-null   object
#  21  cip_norm                9957 non-null   object
#  22  c_norm                  9957 non-null   object
#  23  co-trimoxazole_norm     9957 non-null   object
#  24  furanes_norm            9957 non-null   object
#  25  colistine_norm          9957 non-null   object
# dtypes: boolean(3), object(23)
# memory usage: 1.8+ MB

# %%
# Numeric columns
num_cols = ['infection_freq', 'age']
data_raw[num_cols] = data_raw[num_cols].apply(pd.to_numeric, errors='coerce')

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9960 entries, 0 to 9959
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9960 non-null   object
#  1   address                 9960 non-null   object
#  2   diabetes                9947 non-null   boolean
#  3   hypertension            9947 non-null   boolean
#  4   hospital_before         9947 non-null   boolean
#  5   infection_freq          9714 non-null   float64
#  6   collection_date         8474 non-null   object
#  7   notes                   9960 non-null   object
#  8   age                     9947 non-null   float64
#  9   gender                  9947 non-null   object
#  10  strain_norm             9947 non-null   object
#  11  amx/amp_norm            9957 non-null   object
#  12  amc_norm                9957 non-null   object
#  13  cz_norm                 9957 non-null   object
#  14  fox_norm                9957 non-null   object
#  15  ctx/cro_norm            9957 non-null   object
#  16  ipm_norm                9957 non-null   object
#  17  gen_norm                9957 non-null   object
#  18  an_norm                 9957 non-null   object
#  19  acide_nalidixique_norm  9957 non-null   object
#  20  ofx_norm                9957 non-null   object
#  21  cip_norm                9957 non-null   object
#  22  c_norm                  9957 non-null   object
#  23  co-trimoxazole_norm     9957 non-null   object
#  24  furanes_norm            9957 non-null   object
#  25  colistine_norm          9957 non-null   object
# dtypes: boolean(3), float64(2), object(21)
# memory usage: 1.8+ MB

# %%
# Categorical columns
cat_cols = [
    "gender",'amx/amp_norm', 'amc_norm', 'cz_norm', 'fox_norm', 'ctx/cro_norm', 'ipm_norm', 'gen_norm',
    'an_norm', 'acide_nalidixique_norm', 'ofx_norm', 'cip_norm', 'c_norm',
    'co-trimoxazole_norm', 'furanes_norm', 'colistine_norm'
]
data_raw[cat_cols] = data_raw[cat_cols].astype('category')

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9960 entries, 0 to 9959
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      9960 non-null   object
#  1   address                 9960 non-null   object
#  2   diabetes                9947 non-null   boolean
#  3   hypertension            9947 non-null   boolean
#  4   hospital_before         9947 non-null   boolean
#  5   infection_freq          9714 non-null   float64
#  6   collection_date         8474 non-null   object
#  7   notes                   9960 non-null   object
#  8   age                     9947 non-null   float64
#  9   gender                  9947 non-null   category
#  10  strain_norm             9947 non-null   object
#  11  amx/amp_norm            9957 non-null   category
#  12  amc_norm                9957 non-null   category
#  13  cz_norm                 9957 non-null   category
#  14  fox_norm                9957 non-null   category
#  15  ctx/cro_norm            9957 non-null   category
#  16  ipm_norm                9957 non-null   category
#  17  gen_norm                9957 non-null   category
#  18  an_norm                 9957 non-null   category
#  19  acide_nalidixique_norm  9957 non-null   category
#  20  ofx_norm                9957 non-null   category
#  21  cip_norm                9957 non-null   category
#  22  c_norm                  9957 non-null   category
#  23  co-trimoxazole_norm     9957 non-null   category
#  24  furanes_norm            9957 non-null   category
#  25  colistine_norm          9957 non-null   category
# dtypes: boolean(3), category(16), float64(2), object(5)
# memory usage: 760.9+ KB

# %%
# Droping columns
# data_raw.drop(columns=['id', 'name', 'email', 'address', 'notes','collection_date'], inplace=True)
# data_raw.reset_index(drop=True, inplace=True)

# %%
sns.heatmap(data_raw.isna())
# Out:
# <Axes: >
